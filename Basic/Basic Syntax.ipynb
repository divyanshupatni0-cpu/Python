# %%
# variable
#variable is container which store the value in meomry location
a=10
b=20
print(a+b)
# Out:
# 30

# %%
#datatype
#data type is classification which tells the computer which type of value stored in the variable and what kind of opretion perform on it
#ex- list tuple dictionary set string int float complex
lst=[1,2,3.4]
print(type(lst))
print(lst)
# Out:
# <class 'list'>
# [1, 2, 3.4]

# %%
#opretor
#opretor is a symbol which perform specific task on oprend 
a=20
b=90
print(a+b)
print(a-b)
print(a*b)
print(a/b)      #arithmatic opretor
print(a%b)
# Out:
# 110
# -70
# 1800
# 0.2222222222222222
# 20

# %%
# relational opretor
a=10
b=78
print(a>b)
print(a<b)
print(a!=b)
print(a==b)
# Out:
# False
# True
# True
# False

# %%
#assigment opretor
a=4
b=7
print(a>=b)
print(a<=b)
# Out:
# False
# True

# %%
#logical opretor
# a and b
# a or b
#a not b

# %%
#bitwise opretor
a=5
b=7
print(a&b)
print(a|b)
# Out:
# 5
# 7
